# %%
# Import the class from video_license_plate_recognition.py
from v_p import LicensePlateRecognitionVideo  

# Initialize the LicensePlateRecognitionVideo model
model_path = "model/best.pt"  # Update with your trained YOLO model path
video_processor = LicensePlateRecognitionVideo(model_path)

# Process a video file
input_video = "videos/demo.mp4"  # Change this to your actual video path
output_video = "processed_output.mp4"
video_processor.process_video(input_video, output_video)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 0: 416x640 1 licence-plate, 168.2ms
# Speed: 4.4ms preprocess, 168.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 licence-plate, 118.1ms
# Speed: 6.0ms preprocess, 118.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 licence-plates, 112.7ms
# Speed: 5.9ms preprocess, 112.7ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 licence-plate, 112.9ms
# Speed: 6.2ms preprocess, 112.9ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 licence-plates, 110.4ms
# Speed: 4.6ms preprocess, 110.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 licence-plate, 110.2ms
# Speed: 6.0ms preprocess, 110.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 licence-plate, 124.4ms
# ...

# %%
# Import the class from image_preprocessing.py
from i_p import LicensePlateRecognition  

# Initialize the LicensePlateRecognition model
model_path = "model/best.pt"  # Update this with your trained YOLO model path
plate_recognition = LicensePlateRecognition(model_path)  # ✅ Corrected call

# Process a single image
image_path = "images/test.jpg"  # Change this to your actual image path
plate_recognition.process_image(image_path)  # ✅ Corrected call

# Process all images in a folder
folder_path = "images"  # Folder containing multiple images
plate_recognition.process_folder(folder_path)  # ✅ Corrected call
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 🔄 Processing: images/test.jpg
#
# 0: 480x640 1 licence-plate, 182.9ms
# Speed: 10.2ms preprocess, 182.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1024x749>
# ✅ Saved: output\processed_test.jpg
#
# 🔄 Processing: images\test.jpg
#
# 0: 480x640 1 licence-plate, 400.4ms
# Speed: 10.2ms preprocess, 400.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1024x749>
# ✅ Saved: output\processed_test.jpg
